# %%
import numpy as np
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
import os
print(os.getcwd())
import os

# Load the dataset
bike_data = pd.read_csv("Bicycle_Thefts_Open_Data.csv")
# Out:
# C:\Users\novee\DataWareHousing_FinalProject\DataWareHousing_FinalProject\python_server

# %%
bike_data.head().T
# Out:
#                                                                    0  \
# OBJECTID                                                           1
# EVENT_UNIQUE_ID                                       GO-20141263784
# PRIMARY_OFFENCE                                     PROPERTY - FOUND
# OCC_DATE                                         1/1/2014 5:00:00 AM
# OCC_YEAR                                                        2014
# OCC_MONTH                                                    January
# OCC_DOW                                                    Wednesday
# OCC_DAY                                                            1
# OCC_DOY                                                            1
# OCC_HOUR                                                          18
# REPORT_DATE                                      1/1/2014 5:00:00 AM
# REPORT_YEAR                                                     2014
# REPORT_MONTH                                                 January
# REPORT_DOW                                                 Wednesday
# REPORT_DAY                                                         1
# REPORT_DOY                                                         1
# REPORT_HOUR                                                       18
# DIVISION                                                         D14
# LOCATION_TYPE      Single Home, House (Attach Garage, Cottage, Mo...
# PREMISES_TYPE                                                  House
# BIKE_MAKE                                                       TREK
# BIKE_MODEL                                                    SOHO S
# BIKE_TYPE                                                         RG
# BIKE_SPEED                                                       1.0
# BIKE_COLOUR                                                      BLK
# BIKE_COST                                                        NaN
# STATUS                                                     RECOVERED
# HOOD_158                                                         080
# NEIGHBOURHOOD_158                       Palmerston-Little Italy (80)
# HOOD_140                                                         080
# NEIGHBOURHOOD_140                       Palmerston-Little Italy (80)
# LONG_WGS84                                                -79.414654
# LAT_WGS84                                                  43.660525
# x                                                    -8840398.792484
# y                                                     5413057.031695
#
#                                                                    1  \
# OBJECTID                                                           2
# EVENT_UNIQUE_ID                                       GO-20141263544
# PRIMARY_OFFENCE                                                  B&E
# OCC_DATE                                       12/26/2013 5:00:00 AM
# OCC_YEAR                                                        2013
# OCC_MONTH                                                   December
# OCC_DOW                                                     Thursday
# OCC_DAY                                                           26
# OCC_DOY                                                          360
# OCC_HOUR                                                          19
# REPORT_DATE                                      1/1/2014 5:00:00 AM
# REPORT_YEAR                                                     2014
# REPORT_MONTH                                                 January
# REPORT_DOW                                                 Wednesday
# REPORT_DAY                                                         1
# REPORT_DOY                                                         1
# REPORT_HOUR                                                       17
# DIVISION                                                         D14
# LOCATION_TYPE      Other Commercial / Corporate Places (For Profi...
# PREMISES_TYPE                                             Commercial
# BIKE_MAKE                                                       FELT
# BIKE_MODEL                                                       F59
# BIKE_TYPE                                                         RC
# BIKE_SPEED                                                      21.0
# BIKE_COLOUR                                                   SILRED
# BIKE_COST                                                     1300.0
# STATUS                                                        STOLEN
# HOOD_158                                                         165
# NEIGHBOURHOOD_158                       Harbourfront-CityPlace (165)
# HOOD_140                                                         077
# NEIGHBOURHOOD_140             Waterfront Communities-The Island (77)
# LONG_WGS84                                                -79.395643
# LAT_WGS84                                                  43.640021
# x                                                    -8838282.520465
# y                                                     5409902.506271
#
#                                                   2  \
# OBJECTID                                          3
# EVENT_UNIQUE_ID                      GO-20141261431
# PRIMARY_OFFENCE                         THEFT UNDER
# OCC_DATE                        1/1/2014 5:00:00 AM
# OCC_YEAR                                       2014
# OCC_MONTH                                   January
# OCC_DOW                                   Wednesday
# OCC_DAY                                           1
# OCC_DOY                                           1
# OCC_HOUR                                          7
# REPORT_DATE                     1/1/2014 5:00:00 AM
# REPORT_YEAR                                    2014
# REPORT_MONTH                                January
# REPORT_DOW                                Wednesday
# REPORT_DAY                                        1
# REPORT_DOY                                        1
# REPORT_HOUR                                       7
# DIVISION                                        D14
# LOCATION_TYPE      Apartment (Rooming House, Condo)
# PREMISES_TYPE                             Apartment
# BIKE_MAKE                                SUPERCYCLE
# BIKE_MODEL                                      NaN
# BIKE_TYPE                                        MT
# BIKE_SPEED                                     10.0
# BIKE_COLOUR                                     NaN
# BIKE_COST                                       NaN
# STATUS                                       STOLEN
# HOOD_158                                        085
# NEIGHBOURHOOD_158               South Parkdale (85)
# HOOD_140                                        085
# NEIGHBOURHOOD_140               South Parkdale (85)
# LONG_WGS84                               -79.443645
# LAT_WGS84                                 43.637657
# x                                   -8843626.121409
# y                                    5409538.956195
#
#                                                   3  \
# OBJECTID                                          4
# EVENT_UNIQUE_ID                      GO-20141267465
# PRIMARY_OFFENCE                         THEFT UNDER
# OCC_DATE                       9/30/2013 5:00:00 AM
# OCC_YEAR                                       2013
# OCC_MONTH                                 September
# OCC_DOW                                      Monday
# OCC_DAY                                          30
# OCC_DOY                                         273
# OCC_HOUR                                          0
# REPORT_DATE                     1/2/2014 5:00:00 AM
# REPORT_YEAR                                    2014
# REPORT_MONTH                                January
# REPORT_DOW                                 Thursday
# REPORT_DAY                                        2
# REPORT_DOY                                        2
# REPORT_HOUR                                      12
# DIVISION                                        D14
# LOCATION_TYPE      Apartment (Rooming House, Condo)
# PREMISES_TYPE                             Apartment
# BIKE_MAKE                                     NORCO
# BIKE_MODEL                              CHARGER 9.2
# BIKE_TYPE                                        MT
# BIKE_SPEED                                     21.0
# BIKE_COLOUR                                     BLK
# BIKE_COST                                     750.0
# STATUS                                       STOLEN
# HOOD_158                                        078
# NEIGHBOURHOOD_158         Kensington-Chinatown (78)
# HOOD_140                                        078
# NEIGHBOURHOOD_140         Kensington-Chinatown (78)
# LONG_WGS84                               -79.404678
# LAT_WGS84                                 43.648964
# x                                   -8839288.269466
# y                                    5411278.256494
#
#                                                   4
# OBJECTID                                          5
# EVENT_UNIQUE_ID                      GO-20149000074
# PRIMARY_OFFENCE                         THEFT UNDER
# OCC_DATE                      12/25/2013 5:00:00 AM
# OCC_YEAR                                       2013
# OCC_MONTH                                  December
# OCC_DOW                                   Wednesday
# OCC_DAY                                          25
# OCC_DOY                                         359
# OCC_HOUR                                         16
# REPORT_DATE                     1/2/2014 5:00:00 AM
# REPORT_YEAR                                    2014
# REPORT_MONTH                                January
# REPORT_DOW                                 Thursday
# REPORT_DAY                                        2
# REPORT_DOY                                        2
# REPORT_HOUR                                      16
# DIVISION                                        D51
# LOCATION_TYPE      Apartment (Rooming House, Condo)
# PREMISES_TYPE                             Apartment
# BIKE_MAKE                                        CA
# BIKE_MODEL                                 RZ 120 1
# BIKE_TYPE                                        MT
# BIKE_SPEED                                     21.0
# BIKE_COLOUR                                     WHI
# BIKE_COST                                    1500.0
# STATUS                                       STOLEN
# HOOD_158                                        168
# NEIGHBOURHOOD_158         Downtown Yonge East (168)
# HOOD_140                                        075
# NEIGHBOURHOOD_140        Church-Yonge Corridor (75)
# LONG_WGS84                                -79.37269
# LAT_WGS84                                 43.652377
# x                                   -8835727.450502
# y                                    5411803.313675

# %%
print(bike_data.info())
def summarize_dataset(data):
    columns_summary = []
    for column in data.columns:
        data_type = data[column].dtype
        missing_values = data[column].isnull().sum()
        unique_values = data[column].nunique()
        columns_summary.append({
            "Column Name": column,
            "Data Type": data_type,
            "Missing Values": missing_values,
            "Unique Values": unique_values
        })
    return pd.DataFrame(columns_summary)

# Generate the summary for the dataset
columns_summary_df = summarize_dataset(bike_data)

# Save the summary as a CSV file for easy review
columns_summary_path = "C:/Users/novee/DataWareHousing_FinalProject/DataWareHousing_FinalProject/python_server/dataset_columns_summary.csv"
columns_summary_df.to_csv(columns_summary_path, index=False)

columns_summary_path
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37178 entries, 0 to 37177
# Data columns (total 35 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   OBJECTID           37178 non-null  int64
#  1   EVENT_UNIQUE_ID    37178 non-null  object
#  2   PRIMARY_OFFENCE    37178 non-null  object
#  3   OCC_DATE           37178 non-null  object
#  4   OCC_YEAR           37178 non-null  int64
#  5   OCC_MONTH          37178 non-null  object
#  6   OCC_DOW            37178 non-null  object
#  7   OCC_DAY            37178 non-null  int64
#  8   OCC_DOY            37178 non-null  int64
#  9   OCC_HOUR           37178 non-null  int64
#  10  REPORT_DATE        37178 non-null  object
#  11  REPORT_YEAR        37178 non-null  int64
#  12  REPORT_MONTH       37178 non-null  object
#  13  REPORT_DOW         37178 non-null  object
#  14  REPORT_DAY         37178 non-null  int64
#  15  REPORT_DOY         37178 non-null  int64
#  16  REPORT_HOUR        37178 non-null  int64
#  17  DIVISION           37178 non-null  object
#  18  LOCATION_TYPE      37178 non-null  object
#  19  PREMISES_TYPE      37178 non-null  object
#  20  BIKE_MAKE          36995 non-null  object
#  21  BIKE_MODEL         23471 non-null  object
#  22  BIKE_TYPE          37178 non-null  object
#  23  BIKE_SPEED         36043 non-null  float64
#  24  BIKE_COLOUR        33886 non-null  object
#  25  BIKE_COST          34688 non-null  float64
#  26  STATUS             37178 non-null  object
#  27  HOOD_158           37178 non-null  object
#  28  NEIGHBOURHOOD_158  37178 non-null  object
#  29  HOOD_140           37178 non-null  object
#  30  NEIGHBOURHOOD_140  37178 non-null  object
#  31  LONG_WGS84         37178 non-null  float64
#  32  LAT_WGS84          37178 non-null  float64
#  33  x                  37178 non-null  float64
#  34  y                  37178 non-null  float64
# dtypes: float64(6), int64(9), object(20)
# memory usage: 9.9+ MB
# None
# 'C:/Users/novee/DataWareHousing_FinalProject/DataWareHousing_FinalProject/python_server/dataset_columns_summary.csv'

# %%
bike_data.describe().T
# Out:
#                count          mean            std           min           25%  \
# OBJECTID     37178.0  1.858950e+04   10732.508491  1.000000e+00  9.295250e+03
# OCC_YEAR     37178.0  2.018718e+03       2.987905  1.975000e+03  2.016000e+03
# OCC_DAY      37178.0  1.564538e+01       8.637666  1.000000e+00  8.000000e+00
# OCC_DOY      37178.0  1.999308e+02      77.454583  1.000000e+00  1.490000e+02
# OCC_HOUR     37178.0  1.329262e+01       6.526714  0.000000e+00  9.000000e+00
# REPORT_YEAR  37178.0  2.018741e+03       2.968978  2.014000e+03  2.016000e+03
# REPORT_DAY   37178.0  1.597988e+01       8.600372  1.000000e+00  9.000000e+00
# REPORT_DOY   37178.0  2.010057e+02      77.696535  1.000000e+00  1.510000e+02
# REPORT_HOUR  37178.0  1.426395e+01       5.086319  0.000000e+00  1.100000e+01
# BIKE_SPEED   36043.0  1.410271e+01      10.714546  0.000000e+00  6.000000e+00
# BIKE_COST    34688.0  1.000068e+03    1595.093249  0.000000e+00  3.990000e+02
# LONG_WGS84   37178.0 -7.868770e+01       7.458295 -7.962223e+01 -7.941869e+01
# LAT_WGS84    37178.0  4.328573e+01       4.102826  0.000000e+00  4.365028e+01
# x            37178.0 -8.759475e+06  830253.601603 -8.863506e+06 -8.840848e+06
# y            37178.0  5.367007e+06  508722.869972  5.664924e-09  5.411480e+06
#
#                       50%           75%           max
# OBJECTID     1.858950e+04  2.788375e+04  3.717800e+04
# OCC_YEAR     2.019000e+03  2.021000e+03  2.024000e+03
# OCC_DAY      1.600000e+01  2.300000e+01  3.100000e+01
# OCC_DOY      2.030000e+02  2.570000e+02  3.660000e+02
# OCC_HOUR     1.400000e+01  1.800000e+01  2.300000e+01
# REPORT_YEAR  2.019000e+03  2.021000e+03  2.024000e+03
# REPORT_DAY   1.600000e+01  2.300000e+01  3.100000e+01
# REPORT_DOY   2.050000e+02  2.580000e+02  3.660000e+02
# REPORT_HOUR  1.400000e+01  1.800000e+01  2.300000e+01
# BIKE_SPEED   1.500000e+01  2.100000e+01  9.900000e+01
# BIKE_COST    6.799900e+02  1.172540e+03  1.200000e+05
# LONG_WGS84  -7.939067e+01 -7.937281e+01  0.000000e+00
# LAT_WGS84    4.366220e+01  4.368356e+01  4.383724e+01
# x           -8.837728e+06 -8.835740e+06  6.327780e-09
# y            5.413315e+06  5.416603e+06  5.440289e+06

# %%
# Separate numerical and categorical columns
numerical_columns = bike_data.select_dtypes(include=['int64', 'float64'])
categorical_columns = bike_data.select_dtypes(include=['object'])

# Count null values in numerical columns
numerical_nulls = numerical_columns.isnull().sum()

# Count null values in categorical columns
categorical_nulls = categorical_columns.isnull().sum()

numerical_nulls, categorical_nulls
# Out:
# (OBJECTID          0
#  OCC_YEAR          0
#  OCC_DAY           0
#  OCC_DOY           0
#  OCC_HOUR          0
#  REPORT_YEAR       0
#  REPORT_DAY        0
#  REPORT_DOY        0
#  REPORT_HOUR       0
#  BIKE_SPEED     1135
#  BIKE_COST      2490
#  LONG_WGS84        0
#  LAT_WGS84         0
#  x                 0
#  y                 0
#  dtype: int64,
#  EVENT_UNIQUE_ID          0
#  PRIMARY_OFFENCE          0
#  OCC_DATE                 0
#  OCC_MONTH                0
#  OCC_DOW                  0
#  REPORT_DATE              0
#  REPORT_MONTH             0
#  REPORT_DOW               0
#  DIVISION                 0
#  LOCATION_TYPE            0
#  PREMISES_TYPE            0
#  BIKE_MAKE              183
#  BIKE_MODEL           13707
#  BIKE_TYPE                0
#  BIKE_COLOUR           3292
#  STATUS                   0
#  HOOD_158                 0
#  NEIGHBOURHOOD_158        0
#  HOOD_140                 0
#  NEIGHBOURHOOD_140        0
#  dtype: int64)

# %%
# Unique value counts for categorical columns
categorical_uniques = {col: categorical_columns[col].value_counts() for col in categorical_columns.columns}

# Unique value counts for numerical columns
numerical_uniques = {col: numerical_columns[col].nunique() for col in numerical_columns.columns}

categorical_uniques, numerical_uniques
# Out:
# ({'EVENT_UNIQUE_ID': EVENT_UNIQUE_ID
#   GO-2017637379     14
#   GO-20201550944    14
#   GO-20161587221    10
#   GO-20209013342    10
#   GO-20192056126    10
#                     ..
#   GO-20179013582     1
#   GO-20179013642     1
#   GO-20179013586     1
#   GO-20179013636     1
#   GO-20249052489     1
#   Name: count, Length: 33266, dtype: int64,
#   'PRIMARY_OFFENCE': PRIMARY_OFFENCE
#   THEFT UNDER                      16335
#   THEFT UNDER - BICYCLE            14877
#   B&E                               2436
#   THEFT OF EBIKE UNDER $5000        1292
#   PROPERTY - FOUND                   431
#                                    ...
#   ROBBERY - HOME INVASION              1
#   AGGRAVATED ASLT PEACE OFFICER        1
#   MISCHIEF - ENDANGER LIFE             1
#   INTIMATE PARTNER INCIDENT            1
#   EXTORTION                            1
#   Name: count, Length: 77, dtype: int64,
#   'OCC_DATE': OCC_DATE
#   7/29/2020 5:00:00 AM    41
#   8/15/2018 5:00:00 AM    39
#   7/18/2017 5:00:00 AM    37
#   9/20/2017 5:00:00 AM    37
#   8/1/2020 5:00:00 AM     35
#                           ..
#   3/3/2019 5:00:00 AM      1
#   3/19/2024 5:00:00 AM     1
#   2/19/2019 5:00:00 AM     1
#   3/6/2019 5:00:00 AM      1
#   9/28/2024 5:00:00 AM     1
#   Name: count, Length: 3823, dtype: int64,
#   'OCC_MONTH': OCC_MONTH
#   July         5793
#   August       5392
#   June         5024
#   September    4720
#   May          3947
#   October      3495
#   April        2345
#   November     2013
#   March        1376
#   December     1151
#   January      1003
#   February      919
#   Name: count, dtype: int64,
#   'OCC_DOW': OCC_DOW
#   Friday       5659
#   Tuesday      5449
#   Wednesday    5375
#   Thursday     5358
#   Monday       5308
#   Saturday     5076
#   Sunday       4953
#   Name: count, dtype: int64,
#   'REPORT_DATE': REPORT_DATE
#   7/26/2018 5:00:00 AM    41
#   7/3/2014 5:00:00 AM     40
#   8/18/2020 5:00:00 AM    39
#   8/20/2018 5:00:00 AM    39
#   6/18/2019 5:00:00 AM    38
#                           ..
#   2/28/2022 5:00:00 AM     1
#   2/15/2016 5:00:00 AM     1
#   1/25/2024 5:00:00 AM     1
#   3/5/2022 5:00:00 AM      1
#   1/24/2024 5:00:00 AM     1
#   Name: count, Length: 3800, dtype: int64,
#   'REPORT_MONTH': REPORT_MONTH
#   July         5756
#   August       5471
#   June         4914
#   September    4859
#   May          3804
#   October      3497
#   April        2293
#   November     2114
#   March        1352
#   December     1128
#   January      1072
#   February      918
#   Name: count, dtype: int64,
#   'REPORT_DOW': REPORT_DOW
#   Monday       6221
#   Tuesday      6015
#   Wednesday    5945
#   Thursday     5435
#   Friday       5080
#   Sunday       4362
#   Saturday     4120
#   Name: count, dtype: int64,
#   'DIVISION': DIVISION
#   D52    6511
#   D14    6294
#   D51    6022
#   D55    3524
#   D53    3235
#   D11    2484
#   D32    1871
#   D22    1593
#   D13    1349
#   D41     731
#   D43     649
#   D31     638
#   D33     627
#   D42     415
#   D54     391
#   D12     373
#   D23     355
#   NSA     116
#   Name: count, dtype: int64,
#   'LOCATION_TYPE': LOCATION_TYPE
#   Apartment (Rooming House, Condo)                                          9105
#   Streets, Roads, Highways (Bicycle Path, Private Road)                     6918
#   Single Home, House (Attach Garage, Cottage, Mobile)                       5451
#   Parking Lots (Apt., Commercial Or Non-Commercial)                         3486
#   Other Commercial / Corporate Places (For Profit, Warehouse, Corp. Bldg    2903
#   Private Property Structure (Pool, Shed, Detached Garage)                  2898
#   Universities / Colleges                                                    920
#   Bar / Restaurant                                                           781
#   Open Areas (Lakes, Parks, Rivers)                                          633
#   Pharmacy                                                                   490
#   Other Non Commercial / Corporate Places (Non-Profit, Gov'T, Firehall)      472
#   Ttc Subway Station                                                         441
#   Hospital / Institutions / Medical Facilities (Clinic, Dentist, Morgue)     381
#   Schools During Supervised Activity                                         365
#   Schools During Un-Supervised Activity                                      336
#   Convenience Stores                                                         308
#   Go Station                                                                 301
#   Bank And Other Financial Institutions (Money Mart, Tsx)                    233
#   Unknown                                                                    168
#   Commercial Dwelling Unit (Hotel, Motel, B & B, Short Term Rental)          117
#   Nursing Home                                                                73
#   Police / Courts (Parole Board, Probation Office)                            54
#   Religious Facilities (Synagogue, Church, Convent, Mosque)                   54
#   Homeless Shelter / Mission                                                  48
#   Construction Site (Warehouse, Trailer, Shed)                                41
#   Group Homes (Non-Profit, Halfway House, Social Agency)                      36
#   Gas Station (Self, Full, Attached Convenience)                              34
#   Dealership (Car, Motorcycle, Marine, Trailer, Etc.)                         21
#   Go Train                                                                    16
#   Ttc Bus                                                                     16
#   Group Homes (Non-Profit, Halfway House,                                     11
#   Ttc Bus Stop / Shelter / Loop                                               10
#   Go Bus                                                                       8
#   Other Passenger Train Station                                                8
#   Ttc Subway Train                                                             7
#   Retirement Home                                                              7
#   Ttc Admin Or Support Facility                                                5
#   Ttc Street Car                                                               4
#   Community Group Home                                                         3
#   Other Regional Transit System Vehicle                                        3
#   Ttc Light Rail Transit Station                                               3
#   Jails / Detention Centres                                                    2
#   Other Train Tracks                                                           2
#   Other Train Yard                                                             2
#   Other Train Admin Or Support Facility                                        1
#   Other Passenger Train                                                        1
#   Ttc Subway Tunnel / Outdoor Tracks                                           1
#   Name: count, dtype: int64,
#   'PREMISES_TYPE': PREMISES_TYPE
#   Outside        11049
#   Apartment       9105
#   House           5451
#   Other           4699
#   Commercial      4438
#   Educational     1621
#   Transit          815
#   Name: count, dtype: int64,
#   'BIKE_MAKE': BIKE_MAKE
#   OT            7533
#   UK            3930
#   GI            2217
#   OTHER         2128
#   TR            1982
#                 ...
#   MARYN            1
#   KUOTO            1
#   BIRA             1
#   TREK 6500        1
#   JASION EB7       1
#   Name: count, Length: 1221, dtype: int64,
#   'BIKE_MODEL': BIKE_MODEL
#   UNKNOWN            407
#   HYBRID             168
#   ESCAPE             129
#   SIRRUS             119
#   MOUNTAIN BIKE       95
#                     ...
#   FITNESS BIKE         1
#   2013 TREK 1.2        1
#   TOUGHROAD SLR L      1
#   CUILLIN PRO          1
#   TREK 700 MULTIT      1
#   Name: count, Length: 11488, dtype: int64,
#   'BIKE_TYPE': BIKE_TYPE
#   MT    11474
#   RG    10207
#   OT     5502
#   RC     3516
#   EL     2971
#   TO     1743
#   SC      824
#   BM      495
#   FO      300
#   TR       84
#   TA       25
#   RE       19
#   UN       18
#   Name: count, dtype: int64,
#   'BIKE_COLOUR': BIKE_COLOUR
#   BLK       11046
#   GRY        3454
#   BLU        3315
#   WHI        2638
#   RED        2381
#             ...
#   DBLSIL        1
#   GRYMUL        1
#   SILBGE        1
#   GLDGRN        1
#   GLDGRY        1
#   Name: count, Length: 283, dtype: int64,
#   'STATUS': STATUS
#   NOT RECOVERED    36789
#   RECOVERED          389
#   Name: count, dtype: int64,
#   'HOOD_158': HOOD_158
#   170    2215
#   168    1666
#   164    1338
#   166    1322
#   095    1307
#          ...
#   003      17
#   004      14
#   028      13
#   112      12
#   029       8
#   Name: count, Length: 159, dtype: int64,
#   'NEIGHBOURHOOD_158': NEIGHBOURHOOD_158
#   Yonge-Bay Corridor (170)                  2215
#   Downtown Yonge East (168)                 1666
#   Wellington Place (164)                    1338
#   St Lawrence-East Bayfront-The Islands     1322
#   Annex (95)                                1307
#                                             ...
#   Thistletown-Beaumond Heights (3)            17
#   Rexdale-Kipling (4)                         14
#   Rustic (28)                                 13
#   Beechborough-Greenbrook (112)               12
#   Maple Leaf (29)                              8
#   Name: count, Length: 159, dtype: int64,
#   'HOOD_140': HOOD_140
#   077    3724
#   076    3015
#   075    2744
#   082    1320
#   095    1307
#          ...
#   003      17
#   004      14
#   028      13
#   112      12
#   029       8
#   Name: count, Length: 141, dtype: int64,
#   'NEIGHBOURHOOD_140': NEIGHBOURHOOD_140
#   Waterfront Communities-The Island (77)    3724
#   Bay Street Corridor (76)                  3015
#   Church-Yonge Corridor (75)                2744
#   Niagara (82)                              1320
#   Annex (95)                                1307
#                                             ...
#   Thistletown-Beaumond Heights (3)            17
#   Rexdale-Kipling (4)                         14
#   Rustic (28)                                 13
#   Beechborough-Greenbrook (112)               12
#   Maple Leaf (29)                              8
#   Name: count, Length: 141, dtype: int64},
#  {'OBJECTID': 37178,
#   'OCC_YEAR': 19,
#   'OCC_DAY': 31,
#   'OCC_DOY': 366,
#   'OCC_HOUR': 24,
#   'REPORT_YEAR': 11,
#   'REPORT_DAY': 31,
#   'REPORT_DOY': 366,
#   'REPORT_HOUR': 24,
#   'BIKE_SPEED': 71,
#   'BIKE_COST': 2194,
#   'LONG_WGS84': 7150,
#   'LAT_WGS84': 7150,
#   'x': 7149,
#   'y': 7149})

# %%
bike_data.isnull().sum()
# Out:
# OBJECTID                 0
# EVENT_UNIQUE_ID          0
# PRIMARY_OFFENCE          0
# OCC_DATE                 0
# OCC_YEAR                 0
# OCC_MONTH                0
# OCC_DOW                  0
# OCC_DAY                  0
# OCC_DOY                  0
# OCC_HOUR                 0
# REPORT_DATE              0
# REPORT_YEAR              0
# REPORT_MONTH             0
# REPORT_DOW               0
# REPORT_DAY               0
# REPORT_DOY               0
# REPORT_HOUR              0
# DIVISION                 0
# LOCATION_TYPE            0
# PREMISES_TYPE            0
# BIKE_MAKE              183
# BIKE_MODEL           13707
# BIKE_TYPE                0
# BIKE_SPEED            1135
# BIKE_COLOUR           3292
# BIKE_COST             2490
# STATUS                   0
# HOOD_158                 0
# NEIGHBOURHOOD_158        0
# HOOD_140                 0
# NEIGHBOURHOOD_140        0
# LONG_WGS84               0
# LAT_WGS84                0
# x                        0
# y                        0
# dtype: int64

# %%
def barplots_numerical_bike_data(bike_data, nLower=2, nUpper=1000):
  
    # Filter numerical columns
    numerical_columns = bike_data.select_dtypes(include=['int64', 'float64'])
    
    # Further filter based on unique value thresholds
    numerical_columns = numerical_columns[
        [col for col in numerical_columns if numerical_columns.nunique()[col] > nLower and numerical_columns.nunique()[col] < nUpper]
    ]
    
    # Check the number of numerical columns
    _, nCol = numerical_columns.shape
    if nCol == 0:
        print("No numerical columns found with the specified unique value range.")
        return

    # Calculate rows for subplots
    nColumns = 3
    nGraphRow = int((nCol + nColumns - 1) / nColumns)  # Calculate rows needed for a grid of 3 columns
    fig = plt.figure(num=None, figsize=(7 * 6, int(4 * nGraphRow)), dpi=80, facecolor='w', edgecolor='k')

    # Generate histograms for each numerical column
    for i, col in enumerate(numerical_columns.columns):
        plt.subplot(nGraphRow, nColumns, i + 1)
        numerical_columns[col].hist()
        plt.ylabel('Counts')
        plt.title(f'{col}')

    # Adjust layout and display
    plt.subplots_adjust(hspace=0.5, wspace=0.3)
    plt.show()

# general view of features
barplots_numerical_bike_data(bike_data, nLower=1, nUpper=1000)

# %%
def barplots_categorical_bike_data(bike_data, nLower=2, nUpper=100):
 

    # Filter categorical columns
    categorical_columns = bike_data.select_dtypes(include=['object'])
    
    # Further filter based on unique value thresholds
    categorical_columns = categorical_columns[
        [col for col in categorical_columns if categorical_columns.nunique()[col] > nLower and categorical_columns.nunique()[col] < nUpper]
    ]
    
    # Check the number of categorical columns
    _, nCol = categorical_columns.shape
    if nCol == 0:
        print("No categorical columns found with the specified unique value range.")
        return

    # Calculate rows for subplots
    nColumns = 3
    nGraphRow = int((nCol + nColumns - 1) / nColumns)  # Calculate rows needed for a grid of 3 columns
    fig = plt.figure(num=None, figsize=(7 * 6, int(4 * nGraphRow)), dpi=80, facecolor='w', edgecolor='k')

    # Generate bar plots for each categorical column
    for i, col in enumerate(categorical_columns.columns):
        plt.subplot(nGraphRow, nColumns, i + 1)
        value_counts = categorical_columns[col].value_counts()
        value_counts.plot.bar()
        plt.ylabel('Counts')
        plt.title(f'{col}')

    # Adjust layout and display
    plt.subplots_adjust(hspace=0.8, wspace=0.5)
    plt.show()

# Apply the function to bike_data
barplots_categorical_bike_data(bike_data, nLower=2, nUpper=100)

# %%
# Display the data range of each column
print("")
print("-------------------------------------")
print("-------- Columns Data Range ---------")
print("-------------------------------------")
print("")
for column in bike_data.columns:
    if bike_data[column].dtype in [np.int64, np.float64]:
        min_value = bike_data[column].min()
        max_value = bike_data[column].max()
        print(f"{column}: Min: {min_value}, Max: {max_value}")
    else:
        unique_values = bike_data[column].unique()
        print(f"Unique values in column '{column}':")
        print(unique_values)

    print("")
# Out:
# -------------------------------------
# -------- Columns Data Range ---------
# -------------------------------------
#
# OBJECTID: Min: 1, Max: 37178
#
# Unique values in column 'EVENT_UNIQUE_ID':
# ['GO-20141263784' 'GO-20141263544' 'GO-20141261431' ... 'GO-20242142612'
#  'GO-20242146623' 'GO-20249052489']
#
# Unique values in column 'PRIMARY_OFFENCE':
# ['PROPERTY - FOUND' 'B&E' 'THEFT UNDER' 'THEFT FROM MOTOR VEHICLE UNDER'
#  'PROPERTY - LOST' "B&E W'INTENT" 'THEFT UNDER - BICYCLE' 'MISCHIEF UNDER'
#  'POSSESSION PROPERTY OBC UNDER' 'THEFT OVER' 'INCIDENT - BICYCLE'
#  'FRAUD UNDER' 'THEFT UNDER - SHOPLIFTING' 'FTC PROBATION ORDER'
#  'INCIDENT' 'PROPERTY - RECOVERED' 'ROBBERY - MUGGING'
#  'CARELESS DRIVING- HTA' 'ROBBERY WITH WEAPON' 'ROBBERY - OTHER'
#  'THEFT OF MOTOR VEHICLE' 'THEFT FROM MOTOR VEHICLE OVER'
#  'POSSESSION PROPERTY OBC OVER' 'SUSPICIOUS INCIDENT'
#  'UNLAWFULLY IN DWELLING-HOUSE' 'FRAUD OVER' 'INTIMATE PARTNER INCIDENT'
#  'MISCHIEF - ENDANGER LIFE' 'MISCHIEF - INTERFERE W-PROP'
#  'ROBBERY - SWARMING' 'AGGRAVATED ASLT PEACE OFFICER' 'ASSAULT'
#  'ASSAULT WITH WEAPON' 'ROBBERY - HOME INVASION'
#  'ARR/WARR EXECUTED NO ADDED CHG' 'TRAFFICKING PROPERTY OBC UNDER'
#  'THEFT OVER - BICYCLE' 'THEFT OF EBIKE UNDER $5000'
#  'THEFT OF EBIKE OVER $5000' 'INFORMATION ONLY' 'LIQUOR - INTOXICATED'
#  'INVALID GO - RMS ONLY' 'THREAT - PERSON'
#  'OTHER FEDERAL STATUTE OFFENCES' 'MHA SEC 16 (FORM 2)'
#  'OBSTRUCT PEACE OFFICER' 'TRESPASS AT NIGHT' 'FTC WITH CONDITIONS'
#  'DRUG - POSS COCAINE (SCHD I)' 'CARRYING CONCEALED WEAPON'
#  'MISCHIEF TO VEHICLE' 'FIRE - DETERMINED' 'DRUG - POSS METH (SCHD I)'
#  'POSSESSION HOUSE BREAK INSTRUM' 'PUBLIC MISCHIEF'
#  'FRAUD - IDENTITY/PERS W-INT' 'DRUG - TRAF OTHER (SCHD I)'
#  'DRUG - TRAF CANNABIS (SCHD II)' 'ASSAULT - RESIST/ PREVENT SEIZ'
#  'ASSAULT - FORCE/THRT/IMPEDE' 'B&E OUT' 'THEFT FROM MAIL / BAG / KEY'
#  'ASSAULT BODILY HARM' 'WEAPON - POSS DANGEROUS PURP'
#  'ASSAULT PEACE OFFICER' 'ROBBERY - BUSINESS' 'LANDLORD / TENANT DISPUTE'
#  'THEFT OVER - SHOPLIFTING' 'MVC-PERSONAL INJURY' 'DRIVING COMPLAINT'
#  'ROBBERY - DELIVERY PERSON' 'SEXUAL ASSAULT'
#  'TRAFFICKING PROPERTY OBC OVER' 'THEFT UNDER - DISTRACTION'
#  'HARASS/INDECENT COMMUNICATIONS' 'FIREARM - UNAUTHORIZED POSSESS'
#  'EXTORTION']
#
# Unique values in column 'OCC_DATE':
# ['1/1/2014 5:00:00 AM' '12/26/2013 5:00:00 AM' '9/30/2013 5:00:00 AM' ...
#  '9/29/2024 5:00:00 AM' '9/30/2024 5:00:00 AM' '9/28/2024 5:00:00 AM']
#
# OCC_YEAR: Min: 1975, Max: 2024
#
# Unique values in column 'OCC_MONTH':
# ['January' 'December' 'September' 'July' 'November' 'June' 'February'
#  'March' 'April' 'October' 'August' 'May']
#
# Unique values in column 'OCC_DOW':
# ['Wednesday' 'Thursday' 'Monday' 'Tuesday' 'Saturday' 'Friday' 'Sunday']
#
# OCC_DAY: Min: 1, Max: 31
#
# OCC_DOY: Min: 1, Max: 366
#
# OCC_HOUR: Min: 0, Max: 23
#
# Unique values in column 'REPORT_DATE':
# ['1/1/2014 5:00:00 AM' '1/2/2014 5:00:00 AM' '1/3/2014 5:00:00 AM' ...
#  '9/28/2024 5:00:00 AM' '9/29/2024 5:00:00 AM' '9/30/2024 5:00:00 AM']
#
# REPORT_YEAR: Min: 2014, Max: 2024
#
# Unique values in column 'REPORT_MONTH':
# ['January' 'February' 'March' 'April' 'May' 'June' 'July' 'August'
#  'September' 'October' 'November' 'December']
#
# Unique values in column 'REPORT_DOW':
# ['Wednesday' 'Thursday' 'Friday' 'Saturday' 'Sunday' 'Monday' 'Tuesday']
#
# REPORT_DAY: Min: 1, Max: 31
#
# REPORT_DOY: Min: 1, Max: 366
#
# REPORT_HOUR: Min: 0, Max: 23
#
# Unique values in column 'DIVISION':
# ['D14' 'D51' 'D53' 'D52' 'D32' 'D13' 'D55' 'D54' 'D11' 'D22' 'D41' 'D43'
#  'D12' 'D23' 'D33' 'D31' 'D42' 'NSA']
#
# Unique values in column 'LOCATION_TYPE':
# ['Single Home, House (Attach Garage, Cottage, Mobile)'
#  'Other Commercial / Corporate Places (For Profit, Warehouse, Corp. Bldg'
#  'Apartment (Rooming House, Condo)'
#  'Streets, Roads, Highways (Bicycle Path, Private Road)'
#  'Private Property Structure (Pool, Shed, Detached Garage)'
#  'Parking Lots (Apt., Commercial Or Non-Commercial)' 'Bar / Restaurant'
#  'Schools During Supervised Activity' 'Convenience Stores'
#  'Construction Site (Warehouse, Trailer, Shed)' 'Ttc Subway Station'
#  'Gas Station (Self, Full, Attached Convenience)'
#  "Other Non Commercial / Corporate Places (Non-Profit, Gov'T, Firehall)"
#  'Open Areas (Lakes, Parks, Rivers)'
#  'Group Homes (Non-Profit, Halfway House, Social Agency)'
#  'Universities / Colleges'
#  'Hospital / Institutions / Medical Facilities (Clinic, Dentist, Morgue)'
#  'Go Station' 'Jails / Detention Centres'
#  'Bank And Other Financial Institutions (Money Mart, Tsx)'
#  'Schools During Un-Supervised Activity' 'Unknown' 'Other Passenger Train'
#  'Other Train Admin Or Support Facility'
#  'Commercial Dwelling Unit (Hotel, Motel, B & B, Short Term Rental)'
#  'Homeless Shelter / Mission' 'Other Train Tracks'
#  'Ttc Bus Stop / Shelter / Loop' 'Group Homes (Non-Profit, Halfway House,'
#  'Police / Courts (Parole Board, Probation Office)'
#  'Religious Facilities (Synagogue, Church, Convent, Mosque)'
#  'Retirement Home' 'Go Train'
#  'Dealership (Car, Motorcycle, Marine, Trailer, Etc.)'
#  'Ttc Admin Or Support Facility' 'Other Regional Transit System Vehicle'
#  'Ttc Bus' 'Ttc Subway Train' 'Pharmacy' 'Ttc Light Rail Transit Station'
#  'Go Bus' 'Other Passenger Train Station' 'Ttc Street Car'
#  'Other Train Yard' 'Community Group Home' 'Nursing Home'
#  'Ttc Subway Tunnel / Outdoor Tracks']
#
# Unique values in column 'PREMISES_TYPE':
# ['House' 'Commercial' 'Apartment' 'Outside' 'Other' 'Educational'
#  'Transit']
#
# Unique values in column 'BIKE_MAKE':
# ['TREK' 'FELT' 'SUPERCYCLE' ... 'NAVEE' 'DECACHLON' 'JASION EB7']
#
# Unique values in column 'BIKE_MODEL':
# ['SOHO S' 'F59' nan ... 'EVO HYBRID' '2016 PRIVATE JA' 'TREK 700 MULTIT']
#
# Unique values in column 'BIKE_TYPE':
# ['RG' 'RC' 'MT' 'TO' 'OT' 'EL' 'SC' 'BM' 'TA' 'FO' 'TR' 'RE' 'UN']
#
# BIKE_SPEED: Min: 0.0, Max: 99.0
#
# Unique values in column 'BIKE_COLOUR':
# ['BLK' 'SILRED' nan 'WHI' 'RED' 'BLU' 'PLE' 'GRY' 'GRN' 'GRNMRN' 'WHITE'
#  'YELRED' 'SILBLU' 'BLURED' 'ONG' 'DBL' 'BLUWHI' 'BRNWHI' 'YEL' 'BLKGRY'
#  'DGR' 'SILBLK' 'GRYWHI' 'BGE' 'BLKWHI' 'BLKRED' 'LBL' 'LGR' 'SIL'
#  'WHIBRN' 'REDWHI' 'BLKBLU' 'MRN' 'GRNWHI' 'BLKYEL' 'WHIBLU' 'WHIRED'
#  'BLUSIL' 'SILWHI' 'BLUGRY' 'GLD' 'BLUONG' 'TRQ' 'GREEN' 'BLKONG' 'CPR'
#  'GRYRED' 'GRNBLK' 'BRN' 'BLUGRN' 'OTH' 'PLEGRY' 'GRNBRN' 'GRNGRY'
#  'CPRGLD' 'PNKPLE' 'REDGRY' 'BLKTRQ' 'PNK' 'BLKSIL' 'GRYSIL' 'ONGBLK'
#  'BLKBGE' 'REDSIL' 'WHIBLK' 'REDBLK' 'BLUBLK' 'YELGRY' 'GRNLGR' 'BLUYEL'
#  'WHIYEL' 'WHISIL' 'GRYBLK' 'BLKGRN' 'BRNGLD' 'GRYONG' 'GLDBRN' 'TAN'
#  'WHIGRN' 'YELWHI' 'BRZ' 'WHIGRY' 'BLKMRN' 'GRYYEL' 'CRM' 'REWHI' 'REDYEL'
#  'PNKSIL' 'BLKPLE' 'WHIPNK' 'BLKPNK' 'BLKGLD' 'MRNYEL' 'SILGRY' 'PLEGRN'
#  'PLESIL' 'PLEWHI' 'ONGWHI' 'WHIONG' 'WHIPLE' 'GRYGRN' 'BRZGRN' 'GRYBLU'
#  'YELBLK' 'GLDSIL' 'WHT' 'WHIGLD' 'BLUE' 'CPRONG' 'BLUBRN' 'PNKRED'
#  'LGRPLE' 'PLEYEL' 'BLKDGR' 'BGEBLK' 'BLKLBL' 'DBLWHI' 'BLUTRQ' 'SILVER'
#  'BLKBRZ' 'GRNYEL' 'BLKLGR' 'YELONG' 'TRQGRY' 'GLDOTH' 'BLACK' 'GRYPNK'
#  'DGRBLU' 'BLUPLE' 'GLDWHI' 'BLUCPR' 'ONGYEL' 'MRNGLD' 'GRNRED' 'YELBLU'
#  'CRMWHI' 'GRNBLU' 'ONGRED' 'BLUPNK' 'YELSIL' 'GREY' 'LBLDBL' 'PNKGRY'
#  'BRZCPR' 'SILPLE' 'BGEYEL' 'LBLWHI' 'SILYEL' 'BGEMRN' 'TRQWHI' 'DGRLBL'
#  'BGESIL' 'BLUOTH' 'REDBRN' 'CPRSIL' 'BRZWHI' 'OTHRED' 'PLEMRN' 'DBLDGR'
#  'CPRBRN' 'BLKMUL' 'REDGRN' 'GRNDGR' 'REDBLU' 'DBLYEL' 'PNKWHI' 'GRNGLD'
#  'GLDGRN' 'PLEBLU' 'SILBGE' 'GRYLBL' 'REDPNK' 'SILGRN' 'GRYLGR' 'GRYMUL'
#  'DBLSIL' 'LGRBLU' 'DGRRED' 'GLDBLK' 'MUL' 'DBLRED' 'LBLSIL' 'GRYPLE'
#  'PNKYEL' 'BURGUN' 'MRNGRY' 'BLKOTH' 'SILPNK' 'TRQBLK' 'MRNSIL' 'SILLGR'
#  'LBLOTH' 'DGRSIL' 'ONGSIL' 'REDGLD' 'BLKTAN' 'CRMBLU' 'BLK WH' 'BUR'
#  'GRNPLE' 'LGRWHI' 'YELGRN' 'REDMRN' 'FRY' 'GRNSIL' 'DARK' 'BLUTWH' 'WHIT'
#  'LBLPLE' 'BRNONG' 'GRYGLD' 'BLKBRN' 'DGRONG' 'ONGGRY' 'BRNBLK' 'GRYOTH'
#  'BRZGRY' 'SILONG' 'WHIOTH' 'PURPLE' 'BLKDBL' 'GRNPNK' 'GRNONG' 'PLEPNK'
#  'DGRGLD' 'SILLBL' 'PLEBLK' 'PNKTRQ' 'DBLLBL' 'BLKCPR' 'DGRGRY' 'BLACK&'
#  '18' 'GRYBRN' 'TRQBLU' 'BLULBL' 'LGRGRY' 'LBLGRY' 'ONGTRQ' 'DBLGRY'
#  'LGRYEL' 'GRNLBL' 'PLERED' 'ONGBLU' 'YELOTH' 'PLEONG' 'BLACVK' 'WHITRQ'
#  'PNKBLU' 'MRNGRN' 'PNKBLK' 'GLDBGE' 'BRNMRN' 'TRQSIL' 'OTHBLK' 'WHILBL'
#  'CELEST' 'GRYCPR' 'GRYTRQ' 'BRNBGE' 'MRNBLK' 'BLUDBL' 'SILTRQ' 'PURP'
#  'DGRGRN' 'LGROTH' 'BRZBLK' 'LGRTRQ' 'TEAL' 'BRNSIL' 'DGRYEL' 'BRNYEL'
#  'DBLPLE' 'BRNGRY' 'CRMBRN' 'DBLBLK' 'BLUTAN' 'GLDONG' 'LBLMRN' 'MRNWHI'
#  'MRNRED' 'BGEGRY' 'BGEONG' 'GLDGRY']
#
# BIKE_COST: Min: 0.0, Max: 120000.0
#
# Unique values in column 'STATUS':
# ['RECOVERED' 'NOT RECOVERED']
#
# Unique values in column 'HOOD_158':
# ['080' '165' '085' '078' '168' '071' '039' '105' '167' '106' '056' '152'
#  '032' '070' '164' '073' '166' '095' '057' '084' '153' '018' '170' '119'
#  '171' '081' '139' '111' '174' '055' '090' '031' '169' '067' '092' '064'
#  '113' '079' '126' '002' '108' '088' '072' '062' '068' '074' '089' '122'
#  '065' '047' '012' '054' '098' '151' '094' '069' '159' '043' '120' '163'
#  '083' '143' '058' '107' '027' '162' '024' '086' '100' '160' '156' '052'
#  '172' '013' '136' '001' '091' '044' '015' '116' '103' '053' '109' '040'
#  '144' '034' '154' '063' '066' '133' '155' '020' '050' '173' '019' '121'
#  '158' '112' '097' '129' '016' '061' '037' '036' '035' '096' '041' '134'
#  '022' '023' '009' '087' '025' '038' '146' 'NSA' '123' '140' '059' '042'
#  '114' '147' '145' '003' '101' '102' '021' '115' '099' '048' '033' '118'
#  '142' '161' '060' '150' '030' '110' '135' '046' '149' '011' '141' '007'
#  '008' '128' '157' '010' '005' '130' '138' '124' '049' '148' '028' '006'
#  '004' '125' '029']
#
# Unique values in column 'NEIGHBOURHOOD_158':
# ['Palmerston-Little Italy (80)' 'Harbourfront-CityPlace (165)'
#  'South Parkdale (85)' 'Kensington-Chinatown (78)'
#  'Downtown Yonge East (168)' 'Cabbagetown-South St.James Town (71)'
#  'Bedford Park-Nortown (39)' 'Lawrence Park North (105)'
#  'Church-Wellesley (167)' 'Humewood-Cedarvale (106)'
#  'Leaside-Bennington (56)' 'East Willowdale (152)'
#  'Englemount-Lawrence (32)' 'South Riverdale (70)'
#  'Wellington Place (164)' 'Moss Park (73)'
#  'St Lawrence-East Bayfront-The Islands ' 'Annex (95)'
#  'Broadview North (57)' 'Little Portugal (84)' 'Avondale (153)'
#  'New Toronto (18)' 'Yonge-Bay Corridor (170)' 'Wexford/Maryvale (119)'
#  'Junction-Wallace Emerson (171)' 'Trinity-Bellwoods (81)'
#  'Scarborough Village (139)' 'Rockcliffe-Smythe (111)'
#  'South Eglinton-Davisville (174)' 'Thorncliffe Park (55)'
#  'Junction Area (90)' 'Yorkdale-Glen Park (31)' 'Bay-Cloverhill (169)'
#  'Playter Estates-Danforth (67)' 'Corso Italia-Davenport (92)'
#  'Woodbine Corridor (64)' 'Weston (113)' 'University (79)'
#  'Dorset Park (126)' 'Mount Olive-Silverstone-Jamestown (2)'
#  'Briar Hill-Belgravia (108)' 'High Park North (88)' 'Regent Park (72)'
#  'East End-Danforth (62)' 'North Riverdale (68)'
#  'North St.James Town (74)' 'Runnymede-Bloor West Village (89)'
#  'Birchcliffe-Cliffside (122)' 'Greenwood-Coxwell (65)'
#  'Don Valley Village (47)' 'Markland Wood (12)' "O'Connor-Parkview (54)"
#  'Rosedale-Moore Park (98)' 'Yonge-Doris (151)' 'Wychwood (94)'
#  'Blake-Jones (69)' 'Etobicoke City Centre (159)' 'Victoria Village (43)'
#  'Clairlea-Birchmount (120)' 'Fort York-Liberty Village (163)'
#  'Dufferin Grove (83)' 'West Rouge (143)' 'Old East York (58)'
#  'Oakwood Village (107)' 'York University Heights (27)'
#  'West Queen West (162)' 'Black Creek (24)' 'Roncesvalles (86)'
#  'Yonge-Eglinton (100)' 'Mimico-Queensway (160)'
#  'Bendale-Glen Andrew (156)' 'Bayview Village (52)'
#  'Dovercourt Village (172)' 'Etobicoke West Mall (13)' 'West Hill (136)'
#  'West Humber-Clairville (1)' 'Weston-Pelham Park (91)'
#  'Flemingdon Park (44)' 'Kingsway South (15)' 'Steeles (116)'
#  'Lawrence Park South (103)' 'Henry Farm (53)' 'Caledonia-Fairbank (109)'
#  'St.Andrew-Windfields (40)' 'Morningside Heights (144)'
#  'Bathurst Manor (34)' 'Oakdale-Beverley Heights (154)' 'The Beaches (63)'
#  'Danforth (66)' 'Centennial Scarborough (133)' 'Downsview (155)'
#  'Alderwood (20)' 'Newtonbrook East (50)' 'North Toronto (173)'
#  'Long Branch (19)' 'Oakridge (121)' 'Islington (158)'
#  'Beechborough-Greenbrook (112)' 'Yonge-St.Clair (97)'
#  'Agincourt North (129)' 'Stonegate-Queensway (16)' 'Taylor-Massey (61)'
#  'Willowdale West (37)' 'Newtonbrook West (36)' 'Westminster-Branson (35)'
#  'Casa Loma (96)' 'Bridle Path-Sunnybrook-York Mills (41)'
#  'Highland Creek (134)' 'Humbermede (22)' 'Pelmo Park-Humberlea (23)'
#  'Edenbridge-Humber Valley (9)' 'High Park-Swansea (87)'
#  'Glenfield-Jane Heights (25)' 'Lansing-Westgate (38)'
#  'Malvern East (146)' 'NSA' 'Cliffcrest (123)' 'Guildwood (140)'
#  'Danforth East York (59)' 'Banbury-Don Mills (42)'
#  'Lambton Baby Point (114)' "L'Amoreaux West (147)" 'Malvern West (145)'
#  'Thistletown-Beaumond Heights (3)' 'Forest Hill South (101)'
#  'Forest Hill North (102)' 'Humber Summit (21)' 'Mount Dennis (115)'
#  'Mount Pleasant East (99)' 'Hillcrest Village (48)' 'Clanton Park (33)'
#  "Tam O'Shanter-Sullivan (118)" 'Woburn North (142)'
#  'Humber Bay Shores (161)' 'Woodbine-Lumsden (60)'
#  'Fenside-Parkwoods (150)' 'Brookhaven-Amesbury (30)'
#  'Keelesdale-Eglinton West (110)' 'Morningside (135)' 'Pleasant View (46)'
#  "Parkwoods-O'Connor Hills (149)" 'Eringate-Centennial-West Deane (11)'
#  'Golfdale-Cedarbrae-Woburn (141)' 'Willowridge-Martingrove-Richview (7)'
#  'Humber Heights-Westmount (8)' 'Agincourt South-Malvern West (128)'
#  'Bendale South (157)' 'Princess-Rosethorn (10)' 'Elms-Old Rexdale (5)'
#  'Milliken (130)' 'Eglinton East (138)' 'Kennedy Park (124)'
#  'Bayview Woods-Steeles (49)' "East L'Amoreaux (148)" 'Rustic (28)'
#  'Kingsview Village-The Westway (6)' 'Rexdale-Kipling (4)' 'Ionview (125)'
#  'Maple Leaf (29)']
#
# Unique values in column 'HOOD_140':
# ['080' '077' '085' '078' '075' '071' '039' '105' '106' '056' '051' '032'
#  '070' '073' '095' '057' '084' '018' '076' '119' '093' '081' '139' '111'
#  '104' '055' '090' '031' '067' '092' '064' '113' '079' '126' '002' '108'
#  '088' '072' '062' '068' '074' '089' '122' '065' '047' '012' '054' '098'
#  '094' '069' '014' '043' '120' '082' '083' '131' '058' '107' '027' '024'
#  '086' '100' '017' '127' '052' '013' '136' '001' '091' '044' '015' '116'
#  '103' '053' '109' '040' '034' '026' '063' '066' '133' '020' '050' '019'
#  '121' '112' '097' '129' '016' '061' '037' '036' '035' '096' '041' '134'
#  '022' '023' '009' '087' '025' '038' '132' 'NSA' '123' '140' '059' '042'
#  '114' '117' '003' '101' '102' '021' '115' '099' '048' '033' '118' '137'
#  '060' '045' '030' '110' '135' '046' '011' '007' '008' '128' '010' '005'
#  '130' '138' '124' '049' '028' '006' '004' '125' '029']
#
# Unique values in column 'NEIGHBOURHOOD_140':
# ['Palmerston-Little Italy (80)' 'Waterfront Communities-The Island (77)'
#  'South Parkdale (85)' 'Kensington-Chinatown (78)'
#  'Church-Yonge Corridor (75)' 'Cabbagetown-South St.James Town (71)'
#  'Bedford Park-Nortown (39)' 'Lawrence Park North (105)'
#  'Humewood-Cedarvale (106)' 'Leaside-Bennington (56)'
#  'Willowdale East (51)' 'Englemount-Lawrence (32)' 'South Riverdale (70)'
#  'Moss Park (73)' 'Annex (95)' 'Broadview North (57)'
#  'Little Portugal (84)' 'New Toronto (18)' 'Bay Street Corridor (76)'
#  'Wexford/Maryvale (119)' 'Dovercourt-Wallace Emerson-Junction (93)'
#  'Trinity-Bellwoods (81)' 'Scarborough Village (139)'
#  'Rockcliffe-Smythe (111)' 'Mount Pleasant West (104)'
#  'Thorncliffe Park (55)' 'Junction Area (90)' 'Yorkdale-Glen Park (31)'
#  'Playter Estates-Danforth (67)' 'Corso Italia-Davenport (92)'
#  'Woodbine Corridor (64)' 'Weston (113)' 'University (79)'
#  'Dorset Park (126)' 'Mount Olive-Silverstone-Jamestown (2)'
#  'Briar Hill-Belgravia (108)' 'High Park North (88)' 'Regent Park (72)'
#  'East End-Danforth (62)' 'North Riverdale (68)'
#  'North St.James Town (74)' 'Runnymede-Bloor West Village (89)'
#  'Birchcliffe-Cliffside (122)' 'Greenwood-Coxwell (65)'
#  'Don Valley Village (47)' 'Markland Wood (12)' "O'Connor-Parkview (54)"
#  'Rosedale-Moore Park (98)' 'Wychwood (94)' 'Blake-Jones (69)'
#  'Islington-City Centre West (14)' 'Victoria Village (43)'
#  'Clairlea-Birchmount (120)' 'Niagara (82)' 'Dufferin Grove (83)'
#  'Rouge (131)' 'Old East York (58)' 'Oakwood Village (107)'
#  'York University Heights (27)' 'Black Creek (24)' 'Roncesvalles (86)'
#  'Yonge-Eglinton (100)' 'Mimico (includes Humber Bay Shores) (17)'
#  'Bendale (127)' 'Bayview Village (52)' 'Etobicoke West Mall (13)'
#  'West Hill (136)' 'West Humber-Clairville (1)' 'Weston-Pelham Park (91)'
#  'Flemingdon Park (44)' 'Kingsway South (15)' 'Steeles (116)'
#  'Lawrence Park South (103)' 'Henry Farm (53)' 'Caledonia-Fairbank (109)'
#  'St.Andrew-Windfields (40)' 'Bathurst Manor (34)'
#  'Downsview-Roding-CFB (26)' 'The Beaches (63)' 'Danforth (66)'
#  'Centennial Scarborough (133)' 'Alderwood (20)' 'Newtonbrook East (50)'
#  'Long Branch (19)' 'Oakridge (121)' 'Beechborough-Greenbrook (112)'
#  'Yonge-St.Clair (97)' 'Agincourt North (129)' 'Stonegate-Queensway (16)'
#  'Taylor-Massey (61)' 'Willowdale West (37)' 'Newtonbrook West (36)'
#  'Westminster-Branson (35)' 'Casa Loma (96)'
#  'Bridle Path-Sunnybrook-York Mills (41)' 'Highland Creek (134)'
#  'Humbermede (22)' 'Pelmo Park-Humberlea (23)'
#  'Edenbridge-Humber Valley (9)' 'High Park-Swansea (87)'
#  'Glenfield-Jane Heights (25)' 'Lansing-Westgate (38)' 'Malvern (132)'
#  'NSA' 'Cliffcrest (123)' 'Guildwood (140)' 'Danforth East York (59)'
#  'Banbury-Don Mills (42)' 'Lambton Baby Point (114)' "L'Amoreaux (117)"
#  'Thistletown-Beaumond Heights (3)' 'Forest Hill South (101)'
#  'Forest Hill North (102)' 'Humber Summit (21)' 'Mount Dennis (115)'
#  'Mount Pleasant East (99)' 'Hillcrest Village (48)' 'Clanton Park (33)'
#  "Tam O'Shanter-Sullivan (118)" 'Woburn (137)' 'Woodbine-Lumsden (60)'
#  'Parkwoods-Donalda (45)' 'Brookhaven-Amesbury (30)'
#  'Keelesdale-Eglinton West (110)' 'Morningside (135)' 'Pleasant View (46)'
#  'Eringate-Centennial-West Deane (11)'
#  'Willowridge-Martingrove-Richview (7)' 'Humber Heights-Westmount (8)'
#  'Agincourt South-Malvern West (128)' 'Princess-Rosethorn (10)'
#  'Elms-Old Rexdale (5)' 'Milliken (130)' 'Eglinton East (138)'
#  'Kennedy Park (124)' 'Bayview Woods-Steeles (49)' 'Rustic (28)'
#  'Kingsview Village-The Westway (6)' 'Rexdale-Kipling (4)' 'Ionview (125)'
#  'Maple Leaf (29)']
#
# LONG_WGS84: Min: -79.6222257847719, Max: 0.0
#
# LAT_WGS84: Min: 0.0, Max: 43.8372369342981
#
# x: Min: -8863505.63021325, Max: 6.327780442533911e-09
#
# y: Min: 5.6649236412909e-09, Max: 5440288.67602217

# %%
# Group data by hour and count occurrences
hourly_trend = bike_data['OCC_HOUR'].value_counts().sort_index()

# Plot the trend
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.plot(hourly_trend.index, hourly_trend.values, marker='o')
plt.title('Thefts by Hour of the Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Thefts')
plt.grid(True)
plt.show()

# %%
# Group data by month and count occurrences
monthly_trend = bike_data['OCC_MONTH'].value_counts().sort_index()

# Plot the trend
plt.figure(figsize=(10, 6))
monthly_trend.plot(kind='bar', color='skyblue')
plt.title('Thefts by Month')
plt.xlabel('Month')
plt.ylabel('Number of Thefts')
plt.xticks(rotation=45)
plt.show()

# %%
# Group data by location type and recovery status
recovery_trend = bike_data.groupby(['LOCATION_TYPE', 'STATUS']).size().unstack()

# Plot recovery rates
recovery_trend.plot(kind='bar', stacked=True, figsize=(12, 6))
plt.title('Recovery Rates by Location Type')
plt.xlabel('Location Type')
plt.ylabel('Number of Bikes')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate recovery rates by bike type
recovery_by_bike_type = bike_data.groupby(['BIKE_TYPE', 'STATUS']).size().unstack()
recovery_by_bike_type['Recovery Rate'] = recovery_by_bike_type['RECOVERED'] / recovery_by_bike_type.sum(axis=1)

# Plot recovery rates
recovery_by_bike_type['Recovery Rate'].sort_values(ascending=False).plot(kind='bar', figsize=(10, 6), color='green')
plt.title('Bike Recovery Rates by Bike Type')
plt.ylabel('Recovery Rate')
plt.xlabel('Bike Type')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate recovery rates by hour of occurrence
recovery_by_hour = bike_data.groupby(['OCC_HOUR', 'STATUS']).size().unstack()
recovery_by_hour['Recovery Rate'] = recovery_by_hour['RECOVERED'] / recovery_by_hour.sum(axis=1)

# Plot recovery rates
recovery_by_hour['Recovery Rate'].plot(kind='line', marker='o', figsize=(10, 6), color='blue')
plt.title('Bike Recovery Rates by Hour of the Day')
plt.ylabel('Recovery Rate')
plt.xlabel('Hour of the Day')
plt.grid(True)
plt.show()

# %%
# Calculate recovery rates by premises type
if 'PREMISES_TYPE' in bike_data.columns and 'STATUS' in bike_data.columns:
    # Group data by premises type and status
    recovery_by_premises = bike_data.groupby(['PREMISES_TYPE', 'STATUS']).size().unstack()

    # Add a recovery rate column
    recovery_by_premises['Recovery Rate'] = (
        recovery_by_premises['RECOVERED'] / recovery_by_premises.sum(axis=1)
    )

    # Sort by recovery rate
    recovery_by_premises = recovery_by_premises.sort_values(by='Recovery Rate', ascending=False)

    # Plot recovery rates
    recovery_by_premises['Recovery Rate'].plot(
        kind='bar', figsize=(12, 6), color='skyblue', edgecolor='black'
    )
    plt.title('Bike Recovery Rates by Premises Type')
    plt.xlabel('Premises Type')
    plt.ylabel('Recovery Rate')
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    # Display the table of recovery rates
    recovery_by_premises
else:
    print("The required columns 'PREMISES_TYPE' and/or 'STATUS' are missing from the dataset.")

# %%
# Calculate recovery rates by neighbourhood_158
if 'NEIGHBOURHOOD_158' in bike_data.columns and 'STATUS' in bike_data.columns:
    # Group data by neighborhood and status
    recovery_by_neighbourhood = bike_data.groupby(['NEIGHBOURHOOD_158', 'STATUS']).size().unstack()

    # Add a recovery rate column
    recovery_by_neighbourhood['Recovery Rate'] = (
        recovery_by_neighbourhood['RECOVERED'] / recovery_by_neighbourhood.sum(axis=1)
    )

    # Sort by recovery rate
    recovery_by_neighbourhood = recovery_by_neighbourhood.sort_values(by='Recovery Rate', ascending=False)

    # Plot recovery rates
    top_neighbourhoods = recovery_by_neighbourhood['Recovery Rate'].head(20)  # Show top 20 neighborhoods
    top_neighbourhoods.plot(
        kind='bar', figsize=(12, 6), color='purple', edgecolor='black'
    )
    plt.title('Top 20 Neighbourhoods by Bike Recovery Rates')
    plt.xlabel('Neighbourhood')
    plt.ylabel('Recovery Rate')
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

    # Display the table of recovery rates
    recovery_by_neighbourhood.head(20)
else:
    print("The required columns 'NEIGHBOURHOOD_158' and/or 'STATUS' are missing from the dataset.")

# %%
from sklearn.preprocessing import LabelEncoder

# List categorical columns
categorical_columns = bike_data.select_dtypes(include=['object']).columns

# Create a copy of bike_data for encoding
label_encoded_data = bike_data.copy()

# Encode each categorical column
for col in categorical_columns:
    encoder = LabelEncoder()
    label_encoded_data[col] = encoder.fit_transform(label_encoded_data[col].astype(str))

# %%
# Select numerical columns
numerical_columns = bike_data.select_dtypes(include=['int64', 'float64'])

# Combine numerical and encoded categorical data
combined_data = pd.concat([numerical_columns, label_encoded_data[categorical_columns]], axis=1)
# Compute correlation matrix
correlation_matrix = combined_data.corr()

# %%
# Calculate correlation with the target (STATUS)
target_correlation = correlation_matrix['STATUS'].drop('STATUS').sort_values(ascending=False)

# Filter correlations based on threshold
correlation_threshold = 0.0005  # Adjust threshold as needed
filtered_correlation = target_correlation[target_correlation.abs() > correlation_threshold]

# Plot the filtered correlation as a horizontal bar chart
plt.figure(figsize=(10, 8))
filtered_correlation.plot(kind='barh', color='skyblue', edgecolor='black')

# Plot configurations
plt.title('Correlation with Target: STATUS_ENCODED (|coef| > 0.0005)', fontsize=14)
plt.xlabel('Correlation', fontsize=12)
plt.ylabel('Feature', fontsize=12)
plt.axvline(0, color='gray', linestyle='--', linewidth=1)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Filter correlations related to the target variable (STATUS_ENCODED)
status_correlation = correlation_matrix['STATUS'].sort_values(ascending=False)

# Display the top correlations with STATUS_ENCODED
print("Top correlations with STATUS:")
print(status_correlation)
# Out:
# Top correlations with STATUS:
# STATUS               1.000000
# PREMISES_TYPE        0.019729
# LOCATION_TYPE        0.017586
# BIKE_SPEED           0.009950
# BIKE_COLOUR          0.009203
# BIKE_COST            0.009172
# NEIGHBOURHOOD_140    0.005188
# HOOD_140             0.001896
# OCC_DOW              0.001697
# x                    0.001507
# LONG_WGS84           0.001507
# REPORT_MONTH         0.001354
# REPORT_DOW           0.000565
# OCC_MONTH            0.000265
# y                   -0.001499
# LAT_WGS84           -0.001501
# BIKE_MODEL          -0.002321
# OCC_HOUR            -0.004367
# HOOD_158            -0.004560
# NEIGHBOURHOOD_158   -0.005209
# REPORT_DATE         -0.005431
# OCC_DATE            -0.006463
# OCC_DAY             -0.008418
# OCC_DOY             -0.010358
# BIKE_TYPE           -0.010667
# REPORT_DOY          -0.010796
# DIVISION            -0.010989
# REPORT_HOUR         -0.012197
# REPORT_DAY          -0.014144
# BIKE_MAKE           -0.017098
# OCC_YEAR            -0.026760
# REPORT_YEAR         -0.027345
# OBJECTID            -0.028454
# EVENT_UNIQUE_ID     -0.032379
# PRIMARY_OFFENCE     -0.050505
# Name: STATUS, dtype: float64

# %%
# Perform analysis on the 'PRIMARY_OFFENCE' column in the bike_data DataFrame

# Step 1: Analyze unique values and their counts
primary_offence_counts = bike_data['PRIMARY_OFFENCE'].value_counts()

# Step 2: Define a threshold for rare categories and group them as 'Others'
rare_threshold = 5
rare_categories = primary_offence_counts[primary_offence_counts < rare_threshold].index

# Replace rare categories with 'Others'
bike_data['PRIMARY_OFFENCE'] = bike_data['PRIMARY_OFFENCE'].apply(
    lambda x: x if x not in rare_categories else 'Others'
)

# Step 3: Recalculate counts after grouping
updated_offence_counts = bike_data['PRIMARY_OFFENCE'].value_counts()

# Step 4: Calculate cumulative percentage to identify dominant categories
primary_offence_percentage = updated_offence_counts.cumsum() / updated_offence_counts.sum() * 100
dominant_categories = primary_offence_percentage[primary_offence_percentage <= 90].index

# Filter the dataset to include only dominant categories
filtered_data = bike_data[bike_data['PRIMARY_OFFENCE'].isin(dominant_categories)]

# Save results for review
updated_offence_counts_path = "C:/Users/novee/DataWareHousing_FinalProject/DataWareHousing_FinalProject/python_server/updated_primary_offence_counts.csv"
filtered_data_path = "C:/Users/novee/DataWareHousing_FinalProject/DataWareHousing_FinalProject/python_server/filtered_bike_data.csv"

updated_offence_counts.to_csv(updated_offence_counts_path)
filtered_data.to_csv(filtered_data_path, index=False)

updated_offence_counts_path, filtered_data_path
# Show the top 10 categories after grouping rare ones as 'Others'
print("Updated Primary Offence Counts (Top 10):")
print(updated_offence_counts.head(10))

# Display the total number of categories after grouping
print(f"\nTotal Number of Categories After Grouping: {len(updated_offence_counts)}")
print("\nDominant Categories (90% Coverage):")
print(dominant_categories)
print("\nFiltered Dataset Information:")
print(filtered_data.info())

# Display the first few rows of the filtered dataset
print("\nSample Rows from the Filtered Dataset:")
print(filtered_data.head())

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import (
    confusion_matrix, accuracy_score, precision_score, recall_score,
    f1_score, roc_curve, auc, classification_report
)
from imblearn.over_sampling import SMOTE
import matplotlib.pyplot as plt

## 4 - Model scoring and evaluation
df = pd.read_csv('Bicycle_Thefts_Open_Data.csv')
df = df.sample(n=10000, random_state=42)

df = df.dropna()  # Drop missing values for simplicity
X = df.drop(columns=['STATUS'])  
y = df['STATUS'] 

# Convert the target variable to binary (0 for 'STOLEN', 1 for 'RECOVERED')
y = (y == 'RECOVERED').astype(int)

# Convert categorical columns to numerical
X = pd.get_dummies(X, drop_first=True)

# Split data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the training set
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

# Apply scaling
scaler = StandardScaler()
X_train_smote_scaled = scaler.fit_transform(X_train_smote)
X_test_scaled = scaler.transform(X_test)

# Logistic Regression
log_reg = LogisticRegression(max_iter=500, solver='lbfgs', class_weight='balanced')
log_reg_params = {'C': [0.01, 0.1, 1, 10, 100], 'solver': ['lbfgs', 'liblinear']}
log_reg_cv = GridSearchCV(log_reg, log_reg_params, cv=5, scoring='accuracy')
log_reg_cv.fit(X_train_smote_scaled, y_train_smote)

# Decision Tree
tree_clf = DecisionTreeClassifier(class_weight='balanced')
tree_params = {'max_depth': [3, 5, 10, None], 'min_samples_split': [2, 5, 10]}
tree_cv = GridSearchCV(tree_clf, tree_params, cv=5, scoring='accuracy')
tree_cv.fit(X_train_smote_scaled, y_train_smote)


# Step 4: Evaluate models
models = {
    "Logistic Regression": log_reg_cv.best_estimator_,
    "Decision Tree": tree_cv.best_estimator_
}

results = {}
plt.figure(figsize=(10, 8))  # For ROC curve plotting

for model_name, model in models.items():
    # Predict using the appropriate scaled or unscaled data
    X_test_input = X_test_scaled if model_name == "Logistic Regression" else X_test
    y_pred = model.predict(X_test_input)
    y_proba = model.predict_proba(X_test_input)[:, 1] if hasattr(model, "predict_proba") else None

    # Calculate metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    confusion = confusion_matrix(y_test, y_pred)

    # Store results
    results[model_name] = {
        "Accuracy": accuracy,
        "Precision": precision,
        "Recall": recall,
        "F1-Score": f1,
        "Confusion Matrix": confusion
    }

    # Print classification report
    print(f"\n{model_name} Classification Report:\n")
    print(classification_report(y_test, y_pred, zero_division=0))

    # Plot ROC curve
    if y_proba is not None:
        fpr, tpr, _ = roc_curve(y_test, y_proba)
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f"{model_name} (AUC = {roc_auc:.2f})")

# Finalize ROC plot
plt.plot([0, 1], [0, 1], 'k--', label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# Step 5: Recommend best model
best_model = max(results, key=lambda k: results[k]['F1-Score'])
print(f"\nBest model based on F1-Score: {best_model}")

# %%
## 5 - Deploying the model (Benjamin Lefebvre - 301234587)

# a) Using a flask framework arrange to turn your selected machine-learning model into an API.
# b) Using the pickle module, arrange for Serialization & Deserialization of your model.

from flask import Flask, request, jsonify
import pickle

app = Flask(__name__)

# Save the model


# Load the model


# API Routes
# Get options of the location names in the dataset ,the bike_type,the bike cost ,premises, neighbourhood
@app.route('/options', methods=['GET'])
def get_options():
    options = {
        'DIVISION': bike_data['DIVISION'].unique().tolist(),
        'LOCATION_TYPE': bike_data['LOCATION_TYPE'].unique().tolist(),
        'PREMISES_TYPE': bike_data['PREMISES_TYPE'].unique().tolist(),
        'NEIGHBOURHOOD_158': bike_data['NEIGHBOURHOOD_158'].unique().tolist(),
    }
    return jsonify(options)

# Predict the status of a bike theft
@app.route('/predict', methods=['POST'])
def predict():
    data = request.get_json()
    
    # Convert the input data into a DataFrame
    input_data = pd.DataFrame(data, index=[0])
    
    # Preprocess the input data
    input_data = preprocessor.preprocess(input_data)
    
    # Make predictions
    prediction = modeler.best_model.predict(input_data)
    
    return jsonify({'prediction': prediction[0]})

# Run the app
if __name__ == '__main__':
    app.run(debug=True, port=5001)
